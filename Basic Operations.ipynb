# %%
#variable
10
# Out:
# 10

# %%
#arthimatic operations
a = 10

# %%
a
# Out:
# 10

# %%
a+20
# Out:
# 30

# %%
b = a+20

# %%
b
# Out:
# 30

# %%
a=2

# %%
b=10

# %%
a/b
# Out:
# 1.0

# %%
a%b
# Out:
# 0

# %%
type(a)
# Out:
# int

# %%
#single line comment

# %%
#multiline comment
'''priya'''
# Out:
# 'priya'

# %%
#data types

# %%
a=10

# %%
type(a)
# Out:
# int

# %%
b=45.3

# %%
type(b)
# Out:
# float

# %%
s='This is python'

# %%
s
# Out:
# 'This is python'

# %%
type(s)
# Out:
# str

# %%
b=T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9628\782434843.py in <module>
# ----> 1 b=T
#
# NameError: name 'T' is not defined

# %%
b=True

# %%
type(b)
# Out:
# bool

# %%
#Type casting- used to change the data types

# %%
x=10

# %%
type(x)
# Out:
# int

# %%
float(x)
# Out:
# 10.0

# %%
type(x)
# Out:
# int

# %%
x=float(x)

# %% [raw]
# str(x)

# %%
x=str(x)

# %%
type(x)
# Out:
# str

# %%
a=10

# %%
type(a)
# Out:
# int

# %%
# bool(a)

# %%
z=0

# %%
type(0)
# Out:
# int

# %%
bool(z)
# Out:
# False
